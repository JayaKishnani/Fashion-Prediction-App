# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

data = pd.read_csv(r'C:\Users\HP\Desktop\assignment-codemonk\Task1\crop_production.csv')

# %%
data
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %%
data.isnull().sum() #To check missing values
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
data.shape
# Out:
# (246091, 7)

# %%
# We can choose to either fill the missing values with mean/median
# depending upon skewness of the data. Or we can drop the rows with
# missing values. Or we can apply regression techniques to fill the 
# missing values, whichever applicable.
new_data = data.dropna()

# %%
new_data.isnull().sum()
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %%
new_data
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %% [markdown]
# # Barplots

# %%
plt.figure(figsize=(8,20))
new_data.State_Name.value_counts().sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,150))
new_data.District_Name.value_counts().sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,20))
new_data.Crop_Year.value_counts().sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,20))
new_data.Season.value_counts().sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,20))
new_data.Crop.value_counts().sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Handling categorical data

# %%
#Convert the object data type to categorical and then assign
#the categorical or numeric values 

new_data[new_data.select_dtypes(['object']).columns] = new_data.select_dtypes(['object']).apply(lambda x: x.astype('category').cat.codes)

# %%
new_data.describe()
# Out:
#           State_Name  District_Name      Crop_Year         Season  \
# count  242361.000000  242361.000000  242361.000000  242361.000000
# mean       17.382066     311.205441    2005.625773       2.169466
# std         9.930927     187.294251       4.958285       1.285996
# min         0.000000       0.000000    1997.000000       0.000000
# 25%         9.000000     144.000000    2002.000000       1.000000
# 50%        16.000000     303.000000    2006.000000       2.000000
# 75%        27.000000     473.000000    2010.000000       4.000000
# max        32.000000     645.000000    2015.000000       5.000000
#
#                 Crop          Area    Production
# count  242361.000000  2.423610e+05  2.423610e+05
# mean       68.495080  1.216741e+04  5.825034e+05
# std        34.059499  5.085744e+04  1.706581e+07
# min         0.000000  1.000000e-01  0.000000e+00
# 25%        43.000000  8.700000e+01  8.800000e+01
# 50%        65.000000  6.030000e+02  7.290000e+02
# ...

# %% [markdown]
# # Histograms plots to show data distribution

# %%
#Check data distribution
new_data.hist(bins=20, figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'State_Name'}>,
#         <AxesSubplot:title={'center':'District_Name'}>,
#         <AxesSubplot:title={'center':'Crop_Year'}>],
#        [<AxesSubplot:title={'center':'Season'}>,
#         <AxesSubplot:title={'center':'Crop'}>,
#         <AxesSubplot:title={'center':'Area'}>],
#        [<AxesSubplot:title={'center':'Production'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
map = new_data.corr()

# Create the heatmap using the `heatmap` function of Seaborn
sns.heatmap(map, cmap='coolwarm', annot=True)

# Display the heatmap using the `show` method of the `pyplot` module from matplotlib.
plt.show()

# %% [markdown]
# So we generally remove the features that are highly correlated to the other feature.
#
# For this dataset, we don't need to
